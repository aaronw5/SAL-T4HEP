# %%
import numpy as np

# %%
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

# %%
import tensorflow as tf
import numpy as np

def compute_pairwise_mask(raw_input, alpha=1.0):
    """
    Compute a pairwise delta R mask from raw_input.
    
    raw_input: Tensor of shape (batch, seq_len, 3) with columns [pt, eta, phi].
    alpha: Scale factor for the pairwise mask (e.g. -alpha * delta_R).
    
    Returns:
        pairwise_mask: Tensor of shape (batch, seq_len, seq_len)
    """
    # Extract eta and phi for each particle.
    coords = raw_input[..., 1:3]  # shape: (batch, seq_len, 2)
    
    # Create pairwise differences using broadcasting.
    coords_i = tf.expand_dims(coords, axis=2)  # shape: (batch, seq_len, 1, 2)
    coords_j = tf.expand_dims(coords, axis=1)  # shape: (batch, 1, seq_len, 2)
    diff = coords_i - coords_j  # shape: (batch, seq_len, seq_len, 2)
    
    # Compute delta R (using a small epsilon to avoid sqrt(0)).
    delta_r = tf.sqrt(tf.reduce_sum(tf.square(diff), axis=-1) + 1e-8)
    
    # Return an attention bias where smaller delta R gives a larger (less negative) contribution.
    return delta_r

class CustomMultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, alpha=1.0, **kwargs):
        """
        Custom multi-head attention with integrated pairwise delta R bias.
        
        d_model: Model dimension.
        num_heads: Number of attention heads.
        alpha: Scale factor for the pairwise mask.
        """
        super(CustomMultiHeadAttention, self).__init__(**kwargs)
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"
        self.d_model = d_model
        self.num_heads = num_heads
        self.depth = d_model // num_heads
        self.alpha = alpha

    def build(self, input_shape):
        # Create weight matrices for Q, K, and V.
        self.wq = self.add_weight(shape=(self.d_model, self.d_model),
                                  initializer='glorot_uniform',
                                  trainable=True,
                                  name="wq")
        self.wk = self.add_weight(shape=(self.d_model, self.d_model),
                                  initializer='glorot_uniform',
                                  trainable=True,
                                  name="wk")
        self.wv = self.add_weight(shape=(self.d_model, self.d_model),
                                  initializer='glorot_uniform',
                                  trainable=True,
                                  name="wv")
        self.dense = tf.keras.layers.Dense(self.d_model)
        super(CustomMultiHeadAttention, self).build(input_shape)

    def split_heads(self, x, batch_size):
        # Split the last dimension into (num_heads, depth) and transpose.
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, x, raw_input=None):
        """
        x: Tensor of shape (batch, seq_len, d_model) -- the embedded inputs.
        raw_input: Tensor of shape (batch, seq_len, 3) -- the original [pt, eta, phi],
                   used to compute the pairwise mask.
        """
        batch_size = tf.shape(x)[0]

        # Linear projections for Q, K, V.
        q = tf.matmul(x, self.wq)
        k = tf.matmul(x, self.wk)
        v = tf.matmul(x, self.wv)

        # Split into multiple heads.
        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)

        # Compute scaled dot-product attention logits.
        matmul_qk = tf.matmul(q, k, transpose_b=True)
        dk = tf.cast(self.depth, tf.float32)
        scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

        # Include pairwise delta R computations in the graph.
        if raw_input is not None:
            pairwise_mask = compute_pairwise_mask(raw_input, alpha=self.alpha)
            # Broadcast to all heads: shape becomes (batch, 1, seq_len, seq_len).
            pairwise_mask = tf.expand_dims(pairwise_mask, axis=1)
            scaled_attention_logits += pairwise_mask

        # Softmax to get attention weights.
        attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)
        # Compute the attention output.
        scaled_attention = tf.matmul(attention_weights, v)
        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model))
        output = self.dense(concat_attention)
        return output

class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, d_model, d_ff, output_dim, num_heads, alpha=1.0, **kwargs):
        super(TransformerBlock, self).__init__(**kwargs)
        self.mha = CustomMultiHeadAttention(d_model, num_heads, alpha=alpha)
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.ffn = tf.keras.Sequential([
            tf.keras.layers.Dense(d_ff, activation='relu'),
            tf.keras.layers.Dense(d_model)
        ])
        self.outD = tf.keras.layers.Dense(output_dim)

    def call(self, x, raw_input=None):
        # Pass the raw_input into the attention layer so that pairwise computations
        # are part of the computation graph.
        attn_output = self.mha(x, raw_input=raw_input)
        out1 = self.layernorm1(x + attn_output)
        ffn_output = self.ffn(out1)
        out2 = self.layernorm2(x + ffn_output)
        out2 = self.outD(out2)
        return out2

class AggregationLayer(tf.keras.layers.Layer):
    """
    Aggregates a set of features over the sequence dimension.
    Supported aggregations: "mean" or "max".
    """
    def __init__(self, aggreg="mean", **kwargs):
        super(AggregationLayer, self).__init__(**kwargs)
        self.aggreg = aggreg

    def call(self, inputs):
        if self.aggreg == "mean":
            return tf.reduce_mean(inputs, axis=1)
        elif self.aggreg == "max":
            return tf.reduce_max(inputs, axis=1)
        else:
            raise ValueError("Aggregation not implemented. Use 'mean' or 'max'.")

def build_custom_transformer_classifier(num_particles, feature_dim,
                                        d_model=8, d_ff=8, output_dim=8,
                                        num_heads=8, alpha=1.0):
    """
    Build a classifier model with:
      - A linear embedding layer.
      - Multiple transformer blocks with integrated pairwise computations.
      - Aggregation over the sequence dimension.
      - A final classification layer.
    """
    inputs = tf.keras.layers.Input(shape=(num_particles, feature_dim))
    
    # Linear embedding.
    x = tf.keras.layers.Dense(d_model, activation='relu')(inputs)
    
    # Stacked Transformer blocks. Pass raw_input into each block so the
    # pairwise delta R computation becomes part of the forward pass.
    x = TransformerBlock(d_model, d_ff, output_dim=d_model, num_heads=num_heads, alpha=alpha)(x, raw_input=None)
    
    # Aggregate over the particle (sequence) dimension.
    pooled_output = AggregationLayer(aggreg='max')(x)
    
    # Final dense layers for classification.
    x = tf.keras.layers.Dense(16, activation='relu')(pooled_output)
    outputs = tf.keras.layers.Dense(5, activation='softmax')(x)
    
    return tf.keras.models.Model(inputs=inputs, outputs=outputs)

# Example instantiation:
num_particles = 32
feature_dim = 3  # [pt, eta, phi]
model = build_custom_transformer_classifier(
    num_particles=num_particles,
    feature_dim=feature_dim,
    d_model=16,
    d_ff=16,
    output_dim=16,
    num_heads=4,
    alpha=2.0
)
model.summary()
# Out:
# 2025-03-27 14:26:32.908114: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2025-03-27 14:26:32.908144: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2025-03-27 14:26:32.908152: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2025-03-27 14:26:32.908167: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-03-27 14:26:32.908178: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32, 16)         │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block               │ (None, 32, 16)         │         1,920 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ aggregation_layer               │ (None, 16)             │             0 │
# │ (AggregationLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 5)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,341 (9.14 KB)
#  Trainable params: 2,341 (9.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train = np.load("/Users/anrunw/Downloads/l1-jet-id/data/jetid/processed/x_train_robust_32const_ptetaphi.npy")
y_train = np.load("/Users/anrunw/Downloads/l1-jet-id/data/jetid/processed/y_train_robust_32const_ptetaphi.npy")

# Perform an 80/20 split on the original training data
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=0.2, random_state=42, shuffle=True
)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32, 16)         │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block               │ (None, 32, 16)         │         1,920 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ aggregation_layer               │ (None, 16)             │             0 │
# │ (AggregationLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 5)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,341 (9.14 KB)
#  Trainable params: 2,341 (9.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=250, 
    batch_size=1024)
# Out:
# Epoch 1/250
# 2025-03-27 00:36:53.086942: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-03-27 00:36:53.091964: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 24s 42ms/step - accuracy: 0.3809 - loss: 1.4215 - val_accuracy: 0.6254 - val_loss: 0.9770
# Epoch 2/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.6406 - loss: 0.9525 - val_accuracy: 0.6667 - val_loss: 0.8945
# Epoch 3/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 19s 38ms/step - accuracy: 0.6791 - loss: 0.8714 - val_accuracy: 0.6987 - val_loss: 0.8269
# Epoch 4/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.7037 - loss: 0.8148 - val_accuracy: 0.7192 - val_loss: 0.7813
# Epoch 5/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 19s 39ms/step - accuracy: 0.7229 - loss: 0.7742 - val_accuracy: 0.7344 - val_loss: 0.7474
# Epoch 6/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.7335 - loss: 0.7475 - val_accuracy: 0.7411 - val_loss: 0.7295
# Epoch 7/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 21s 43ms/step - accuracy: 0.7425 - loss: 0.7278 - val_accuracy: 0.7444 - val_loss: 0.7198
# Epoch 8/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 23s 47ms/step - accuracy: 0.7459 - loss: 0.7176 - val_accuracy: 0.7522 - val_loss: 0.7043
# Epoch 9/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.7510 - loss: 0.7063 - val_accuracy: 0.7539 - val_loss: 0.6964
# Epoch 10/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.7543 - loss: 0.6949 - val_accuracy: 0.7562 - val_loss: 0.6910
# Epoch 11/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.7566 - loss: 0.6901 - val_accuracy: 0.7580 - val_loss: 0.6858
# Epoch 12/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.7586 - loss: 0.6848 - val_accuracy: 0.7597 - val_loss: 0.6825
# Epoch 13/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - accuracy: 0.7603 - loss: 0.6809 - val_accuracy: 0.7587 - val_loss: 0.6815
# Epoch 14/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7618 - loss: 0.6760 - val_accuracy: 0.7466 - val_loss: 0.7077
# Epoch 15/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7631 - loss: 0.6742 - val_accuracy: 0.7632 - val_loss: 0.6714
# Epoch 16/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7636 - loss: 0.6696 - val_accuracy: 0.7625 - val_loss: 0.6714
# Epoch 17/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7650 - loss: 0.6676 - val_accuracy: 0.7658 - val_loss: 0.6650
# Epoch 18/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7671 - loss: 0.6634 - val_accuracy: 0.7661 - val_loss: 0.6643
# Epoch 19/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7671 - loss: 0.6613 - val_accuracy: 0.7651 - val_loss: 0.6642
# Epoch 20/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7667 - loss: 0.6636 - val_accuracy: 0.7673 - val_loss: 0.6622
# Epoch 21/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7678 - loss: 0.6600 - val_accuracy: 0.7679 - val_loss: 0.6601
# Epoch 22/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7677 - loss: 0.6612 - val_accuracy: 0.7693 - val_loss: 0.6592
# Epoch 23/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7691 - loss: 0.6577 - val_accuracy: 0.7685 - val_loss: 0.6584
# Epoch 24/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7701 - loss: 0.6535 - val_accuracy: 0.7681 - val_loss: 0.6577
# Epoch 25/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7697 - loss: 0.6554 - val_accuracy: 0.7695 - val_loss: 0.6557
# Epoch 26/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7696 - loss: 0.6554 - val_accuracy: 0.7672 - val_loss: 0.6609
# Epoch 27/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7703 - loss: 0.6528 - val_accuracy: 0.7668 - val_loss: 0.6609
# Epoch 28/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7713 - loss: 0.6504 - val_accuracy: 0.7724 - val_loss: 0.6482
# Epoch 29/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7738 - loss: 0.6458 - val_accuracy: 0.7667 - val_loss: 0.6628
# Epoch 30/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7725 - loss: 0.6486 - val_accuracy: 0.7722 - val_loss: 0.6491
# Epoch 31/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7724 - loss: 0.6472 - val_accuracy: 0.7726 - val_loss: 0.6474
# Epoch 32/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7712 - loss: 0.6488 - val_accuracy: 0.7721 - val_loss: 0.6488
# Epoch 33/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7739 - loss: 0.6455 - val_accuracy: 0.7733 - val_loss: 0.6474
# Epoch 34/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7737 - loss: 0.6457 - val_accuracy: 0.7716 - val_loss: 0.6493
# Epoch 35/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7736 - loss: 0.6439 - val_accuracy: 0.7731 - val_loss: 0.6446
# Epoch 36/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7753 - loss: 0.6401 - val_accuracy: 0.7697 - val_loss: 0.6536
# Epoch 37/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7738 - loss: 0.6448 - val_accuracy: 0.7681 - val_loss: 0.6588
# Epoch 38/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7727 - loss: 0.6469 - val_accuracy: 0.7735 - val_loss: 0.6446
# Epoch 39/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7755 - loss: 0.6404 - val_accuracy: 0.7719 - val_loss: 0.6495
# Epoch 40/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7756 - loss: 0.6395 - val_accuracy: 0.7734 - val_loss: 0.6447
# Epoch 41/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7760 - loss: 0.6382 - val_accuracy: 0.7744 - val_loss: 0.6416
# Epoch 42/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7746 - loss: 0.6424 - val_accuracy: 0.7742 - val_loss: 0.6423
# Epoch 43/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7744 - loss: 0.6424 - val_accuracy: 0.7744 - val_loss: 0.6427
# Epoch 44/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7767 - loss: 0.6377 - val_accuracy: 0.7756 - val_loss: 0.6388
# Epoch 45/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7755 - loss: 0.6389 - val_accuracy: 0.7736 - val_loss: 0.6428
# Epoch 46/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7767 - loss: 0.6367 - val_accuracy: 0.7758 - val_loss: 0.6397
# Epoch 47/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7765 - loss: 0.6371 - val_accuracy: 0.7755 - val_loss: 0.6400
# Epoch 48/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7774 - loss: 0.6350 - val_accuracy: 0.7753 - val_loss: 0.6392
# Epoch 49/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7751 - loss: 0.6407 - val_accuracy: 0.7748 - val_loss: 0.6412
# Epoch 50/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7766 - loss: 0.6367 - val_accuracy: 0.7759 - val_loss: 0.6369
# Epoch 51/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7762 - loss: 0.6364 - val_accuracy: 0.7764 - val_loss: 0.6363
# Epoch 52/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7771 - loss: 0.6347 - val_accuracy: 0.7757 - val_loss: 0.6390
# Epoch 53/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7772 - loss: 0.6351 - val_accuracy: 0.7765 - val_loss: 0.6358
# Epoch 54/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7781 - loss: 0.6310 - val_accuracy: 0.7673 - val_loss: 0.6598
# Epoch 55/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7779 - loss: 0.6342 - val_accuracy: 0.7765 - val_loss: 0.6361
# Epoch 56/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7764 - loss: 0.6346 - val_accuracy: 0.7744 - val_loss: 0.6408
# Epoch 57/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7779 - loss: 0.6325 - val_accuracy: 0.7754 - val_loss: 0.6387
# Epoch 58/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7780 - loss: 0.6335 - val_accuracy: 0.7776 - val_loss: 0.6325
# Epoch 59/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7791 - loss: 0.6301 - val_accuracy: 0.7773 - val_loss: 0.6334
# Epoch 60/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7783 - loss: 0.6306 - val_accuracy: 0.7774 - val_loss: 0.6331
# Epoch 61/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7788 - loss: 0.6305 - val_accuracy: 0.7754 - val_loss: 0.6396
# Epoch 62/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7776 - loss: 0.6341 - val_accuracy: 0.7756 - val_loss: 0.6384
# Epoch 63/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7791 - loss: 0.6289 - val_accuracy: 0.7762 - val_loss: 0.6345
# Epoch 64/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7798 - loss: 0.6289 - val_accuracy: 0.7787 - val_loss: 0.6303
# Epoch 65/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7791 - loss: 0.6280 - val_accuracy: 0.7750 - val_loss: 0.6379
# Epoch 66/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7791 - loss: 0.6298 - val_accuracy: 0.7776 - val_loss: 0.6325
# Epoch 67/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7790 - loss: 0.6292 - val_accuracy: 0.7785 - val_loss: 0.6289
# Epoch 68/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7797 - loss: 0.6271 - val_accuracy: 0.7785 - val_loss: 0.6298
# Epoch 69/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7788 - loss: 0.6298 - val_accuracy: 0.7752 - val_loss: 0.6375
# Epoch 70/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7789 - loss: 0.6279 - val_accuracy: 0.7769 - val_loss: 0.6335
# Epoch 71/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7796 - loss: 0.6283 - val_accuracy: 0.7788 - val_loss: 0.6300
# Epoch 72/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7800 - loss: 0.6273 - val_accuracy: 0.7766 - val_loss: 0.6348
# Epoch 73/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7797 - loss: 0.6274 - val_accuracy: 0.7782 - val_loss: 0.6303
# Epoch 74/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7801 - loss: 0.6267 - val_accuracy: 0.7781 - val_loss: 0.6330
# Epoch 75/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7819 - loss: 0.6225 - val_accuracy: 0.7780 - val_loss: 0.6319
# Epoch 76/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7791 - loss: 0.6280 - val_accuracy: 0.7797 - val_loss: 0.6266
# Epoch 77/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7815 - loss: 0.6247 - val_accuracy: 0.7789 - val_loss: 0.6295
# Epoch 78/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7820 - loss: 0.6216 - val_accuracy: 0.7771 - val_loss: 0.6331
# Epoch 79/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7798 - loss: 0.6268 - val_accuracy: 0.7772 - val_loss: 0.6344
# Epoch 80/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7807 - loss: 0.6252 - val_accuracy: 0.7766 - val_loss: 0.6340
# Epoch 81/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - accuracy: 0.7802 - loss: 0.6265 - val_accuracy: 0.7801 - val_loss: 0.6257
# Epoch 82/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7812 - loss: 0.6243 - val_accuracy: 0.7776 - val_loss: 0.6320
# Epoch 83/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7813 - loss: 0.6241 - val_accuracy: 0.7736 - val_loss: 0.6415
# Epoch 84/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7813 - loss: 0.6236 - val_accuracy: 0.7787 - val_loss: 0.6275
# Epoch 85/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7799 - loss: 0.6265 - val_accuracy: 0.7805 - val_loss: 0.6245
# Epoch 86/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7813 - loss: 0.6245 - val_accuracy: 0.7799 - val_loss: 0.6273
# Epoch 87/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7813 - loss: 0.6245 - val_accuracy: 0.7796 - val_loss: 0.6263
# Epoch 88/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7827 - loss: 0.6207 - val_accuracy: 0.7803 - val_loss: 0.6249
# Epoch 89/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7817 - loss: 0.6213 - val_accuracy: 0.7774 - val_loss: 0.6321
# Epoch 90/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7809 - loss: 0.6248 - val_accuracy: 0.7808 - val_loss: 0.6253
# Epoch 91/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7819 - loss: 0.6214 - val_accuracy: 0.7786 - val_loss: 0.6298
# Epoch 92/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7822 - loss: 0.6206 - val_accuracy: 0.7799 - val_loss: 0.6266
# Epoch 93/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7820 - loss: 0.6209 - val_accuracy: 0.7812 - val_loss: 0.6221
# Epoch 94/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7828 - loss: 0.6203 - val_accuracy: 0.7775 - val_loss: 0.6305
# Epoch 95/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7813 - loss: 0.6220 - val_accuracy: 0.7815 - val_loss: 0.6218
# Epoch 96/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7810 - loss: 0.6224 - val_accuracy: 0.7819 - val_loss: 0.6220
# Epoch 97/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7823 - loss: 0.6203 - val_accuracy: 0.7795 - val_loss: 0.6269
# Epoch 98/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7819 - loss: 0.6215 - val_accuracy: 0.7819 - val_loss: 0.6217
# Epoch 99/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7829 - loss: 0.6177 - val_accuracy: 0.7759 - val_loss: 0.6362
# Epoch 100/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7817 - loss: 0.6220 - val_accuracy: 0.7810 - val_loss: 0.6235
# Epoch 101/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7838 - loss: 0.6184 - val_accuracy: 0.7795 - val_loss: 0.6269
# Epoch 102/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7822 - loss: 0.6209 - val_accuracy: 0.7796 - val_loss: 0.6268
# Epoch 103/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7824 - loss: 0.6210 - val_accuracy: 0.7814 - val_loss: 0.6224
# Epoch 104/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7815 - loss: 0.6218 - val_accuracy: 0.7766 - val_loss: 0.6349
# Epoch 105/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7823 - loss: 0.6198 - val_accuracy: 0.7808 - val_loss: 0.6245
# Epoch 106/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7825 - loss: 0.6183 - val_accuracy: 0.7807 - val_loss: 0.6240
# Epoch 107/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7826 - loss: 0.6186 - val_accuracy: 0.7814 - val_loss: 0.6222
# Epoch 108/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7819 - loss: 0.6186 - val_accuracy: 0.7816 - val_loss: 0.6217
# Epoch 109/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7823 - loss: 0.6202 - val_accuracy: 0.7816 - val_loss: 0.6204
# Epoch 110/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7829 - loss: 0.6196 - val_accuracy: 0.7823 - val_loss: 0.6202
# Epoch 111/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7812 - loss: 0.6207 - val_accuracy: 0.7809 - val_loss: 0.6219
# Epoch 112/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7818 - loss: 0.6206 - val_accuracy: 0.7812 - val_loss: 0.6220
# Epoch 113/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7827 - loss: 0.6181 - val_accuracy: 0.7814 - val_loss: 0.6212
# Epoch 114/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7828 - loss: 0.6182 - val_accuracy: 0.7815 - val_loss: 0.6217
# Epoch 115/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7822 - loss: 0.6187 - val_accuracy: 0.7813 - val_loss: 0.6214
# Epoch 116/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7843 - loss: 0.6148 - val_accuracy: 0.7821 - val_loss: 0.6221
# Epoch 117/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7833 - loss: 0.6164 - val_accuracy: 0.7809 - val_loss: 0.6224
# Epoch 118/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7826 - loss: 0.6187 - val_accuracy: 0.7816 - val_loss: 0.6230
# Epoch 119/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7824 - loss: 0.6181 - val_accuracy: 0.7795 - val_loss: 0.6266
# Epoch 120/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7824 - loss: 0.6182 - val_accuracy: 0.7804 - val_loss: 0.6235
# Epoch 121/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7834 - loss: 0.6162 - val_accuracy: 0.7817 - val_loss: 0.6202
# Epoch 122/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 24s 49ms/step - accuracy: 0.7831 - loss: 0.6168 - val_accuracy: 0.7782 - val_loss: 0.6292
# Epoch 123/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7827 - loss: 0.6203 - val_accuracy: 0.7821 - val_loss: 0.6208
# Epoch 124/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7833 - loss: 0.6160 - val_accuracy: 0.7814 - val_loss: 0.6219
# Epoch 125/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - accuracy: 0.7850 - loss: 0.6142 - val_accuracy: 0.7820 - val_loss: 0.6190
# Epoch 126/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7835 - loss: 0.6160 - val_accuracy: 0.7813 - val_loss: 0.6218
# Epoch 127/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7842 - loss: 0.6169 - val_accuracy: 0.7820 - val_loss: 0.6195
# Epoch 128/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7838 - loss: 0.6163 - val_accuracy: 0.7811 - val_loss: 0.6224
# Epoch 129/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7835 - loss: 0.6165 - val_accuracy: 0.7808 - val_loss: 0.6233
# Epoch 130/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7838 - loss: 0.6162 - val_accuracy: 0.7818 - val_loss: 0.6203
# Epoch 131/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7828 - loss: 0.6170 - val_accuracy: 0.7823 - val_loss: 0.6188
# Epoch 132/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7832 - loss: 0.6167 - val_accuracy: 0.7822 - val_loss: 0.6191
# Epoch 133/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7831 - loss: 0.6168 - val_accuracy: 0.7814 - val_loss: 0.6218
# Epoch 134/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7832 - loss: 0.6167 - val_accuracy: 0.7807 - val_loss: 0.6248
# Epoch 135/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7840 - loss: 0.6154 - val_accuracy: 0.7825 - val_loss: 0.6190
# Epoch 136/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7846 - loss: 0.6140 - val_accuracy: 0.7810 - val_loss: 0.6233
# Epoch 137/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7834 - loss: 0.6162 - val_accuracy: 0.7820 - val_loss: 0.6189
# Epoch 138/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7841 - loss: 0.6144 - val_accuracy: 0.7817 - val_loss: 0.6201
# Epoch 139/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7829 - loss: 0.6151 - val_accuracy: 0.7820 - val_loss: 0.6200
# Epoch 140/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7843 - loss: 0.6147 - val_accuracy: 0.7820 - val_loss: 0.6210
# Epoch 141/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7838 - loss: 0.6158 - val_accuracy: 0.7812 - val_loss: 0.6233
# Epoch 142/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 35ms/step - accuracy: 0.7842 - loss: 0.6143 - val_accuracy: 0.7799 - val_loss: 0.6249
# Epoch 143/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7835 - loss: 0.6154 - val_accuracy: 0.7825 - val_loss: 0.6182
# Epoch 144/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7829 - loss: 0.6163 - val_accuracy: 0.7803 - val_loss: 0.6243
# Epoch 145/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7836 - loss: 0.6156 - val_accuracy: 0.7812 - val_loss: 0.6205
# Epoch 146/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7832 - loss: 0.6164 - val_accuracy: 0.7777 - val_loss: 0.6302
# Epoch 147/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7827 - loss: 0.6170 - val_accuracy: 0.7820 - val_loss: 0.6201
# Epoch 148/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7833 - loss: 0.6158 - val_accuracy: 0.7829 - val_loss: 0.6181
# Epoch 149/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7843 - loss: 0.6146 - val_accuracy: 0.7827 - val_loss: 0.6182
# Epoch 150/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7839 - loss: 0.6157 - val_accuracy: 0.7823 - val_loss: 0.6179
# Epoch 151/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7842 - loss: 0.6134 - val_accuracy: 0.7834 - val_loss: 0.6160
# Epoch 152/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7847 - loss: 0.6125 - val_accuracy: 0.7832 - val_loss: 0.6158
# Epoch 153/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7831 - loss: 0.6146 - val_accuracy: 0.7829 - val_loss: 0.6168
# Epoch 154/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7839 - loss: 0.6151 - val_accuracy: 0.7816 - val_loss: 0.6196
# Epoch 155/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7849 - loss: 0.6116 - val_accuracy: 0.7828 - val_loss: 0.6175
# Epoch 156/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7844 - loss: 0.6130 - val_accuracy: 0.7803 - val_loss: 0.6252
# Epoch 157/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7833 - loss: 0.6158 - val_accuracy: 0.7837 - val_loss: 0.6155
# Epoch 158/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7835 - loss: 0.6146 - val_accuracy: 0.7827 - val_loss: 0.6168
# Epoch 159/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7839 - loss: 0.6154 - val_accuracy: 0.7831 - val_loss: 0.6173
# Epoch 160/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7847 - loss: 0.6116 - val_accuracy: 0.7821 - val_loss: 0.6188
# Epoch 161/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7835 - loss: 0.6152 - val_accuracy: 0.7824 - val_loss: 0.6175
# Epoch 162/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7842 - loss: 0.6139 - val_accuracy: 0.7829 - val_loss: 0.6175
# Epoch 163/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7839 - loss: 0.6143 - val_accuracy: 0.7828 - val_loss: 0.6175
# Epoch 164/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7841 - loss: 0.6134 - val_accuracy: 0.7783 - val_loss: 0.6282
# Epoch 165/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7844 - loss: 0.6130 - val_accuracy: 0.7795 - val_loss: 0.6241
# Epoch 166/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7834 - loss: 0.6137 - val_accuracy: 0.7796 - val_loss: 0.6237
# Epoch 167/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7834 - loss: 0.6155 - val_accuracy: 0.7808 - val_loss: 0.6224
# Epoch 168/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7841 - loss: 0.6129 - val_accuracy: 0.7827 - val_loss: 0.6182
# Epoch 169/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7846 - loss: 0.6136 - val_accuracy: 0.7834 - val_loss: 0.6154
# Epoch 170/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7842 - loss: 0.6138 - val_accuracy: 0.7832 - val_loss: 0.6162
# Epoch 171/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7848 - loss: 0.6128 - val_accuracy: 0.7825 - val_loss: 0.6183
# Epoch 172/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7847 - loss: 0.6123 - val_accuracy: 0.7805 - val_loss: 0.6228
# Epoch 173/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7844 - loss: 0.6123 - val_accuracy: 0.7835 - val_loss: 0.6163
# Epoch 174/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7839 - loss: 0.6134 - val_accuracy: 0.7775 - val_loss: 0.6295
# Epoch 175/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7852 - loss: 0.6111 - val_accuracy: 0.7820 - val_loss: 0.6204
# Epoch 176/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7860 - loss: 0.6111 - val_accuracy: 0.7835 - val_loss: 0.6150
# Epoch 177/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7851 - loss: 0.6129 - val_accuracy: 0.7834 - val_loss: 0.6159
# Epoch 178/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7850 - loss: 0.6122 - val_accuracy: 0.7832 - val_loss: 0.6153
# Epoch 179/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7845 - loss: 0.6129 - val_accuracy: 0.7811 - val_loss: 0.6219
# Epoch 180/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7846 - loss: 0.6123 - val_accuracy: 0.7818 - val_loss: 0.6184
# Epoch 181/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7852 - loss: 0.6105 - val_accuracy: 0.7828 - val_loss: 0.6154
# Epoch 182/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7853 - loss: 0.6108 - val_accuracy: 0.7812 - val_loss: 0.6202
# Epoch 183/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7852 - loss: 0.6111 - val_accuracy: 0.7807 - val_loss: 0.6227
# Epoch 184/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7854 - loss: 0.6103 - val_accuracy: 0.7836 - val_loss: 0.6154
# Epoch 185/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7839 - loss: 0.6136 - val_accuracy: 0.7835 - val_loss: 0.6165
# Epoch 186/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7847 - loss: 0.6118 - val_accuracy: 0.7834 - val_loss: 0.6163
# Epoch 187/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7850 - loss: 0.6111 - val_accuracy: 0.7820 - val_loss: 0.6185
# Epoch 188/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7837 - loss: 0.6131 - val_accuracy: 0.7797 - val_loss: 0.6257
# Epoch 189/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7841 - loss: 0.6129 - val_accuracy: 0.7836 - val_loss: 0.6140
# Epoch 190/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7851 - loss: 0.6105 - val_accuracy: 0.7837 - val_loss: 0.6138
# Epoch 191/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7850 - loss: 0.6105 - val_accuracy: 0.7794 - val_loss: 0.6281
# Epoch 192/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7851 - loss: 0.6103 - val_accuracy: 0.7839 - val_loss: 0.6165
# Epoch 193/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7854 - loss: 0.6116 - val_accuracy: 0.7841 - val_loss: 0.6144
# Epoch 194/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7853 - loss: 0.6096 - val_accuracy: 0.7829 - val_loss: 0.6160
# Epoch 195/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 41s 85ms/step - accuracy: 0.7844 - loss: 0.6129 - val_accuracy: 0.7805 - val_loss: 0.6244
# Epoch 196/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7854 - loss: 0.6111 - val_accuracy: 0.7828 - val_loss: 0.6191
# Epoch 197/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7840 - loss: 0.6147 - val_accuracy: 0.7821 - val_loss: 0.6186
# Epoch 198/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 178s 368ms/step - accuracy: 0.7850 - loss: 0.6112 - val_accuracy: 0.7821 - val_loss: 0.6177
# Epoch 199/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7847 - loss: 0.6115 - val_accuracy: 0.7813 - val_loss: 0.6196
# Epoch 200/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.7852 - loss: 0.6111 - val_accuracy: 0.7834 - val_loss: 0.6167
# Epoch 201/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 31s 63ms/step - accuracy: 0.7860 - loss: 0.6093 - val_accuracy: 0.7837 - val_loss: 0.6156
# Epoch 202/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7852 - loss: 0.6097 - val_accuracy: 0.7837 - val_loss: 0.6158
# Epoch 203/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.7856 - loss: 0.6095 - val_accuracy: 0.7842 - val_loss: 0.6138
# Epoch 204/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 80s 166ms/step - accuracy: 0.7847 - loss: 0.6125 - val_accuracy: 0.7823 - val_loss: 0.6181
# Epoch 205/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7851 - loss: 0.6100 - val_accuracy: 0.7842 - val_loss: 0.6145
# Epoch 206/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7856 - loss: 0.6092 - val_accuracy: 0.7824 - val_loss: 0.6194
# Epoch 207/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7850 - loss: 0.6123 - val_accuracy: 0.7831 - val_loss: 0.6170
# Epoch 208/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7861 - loss: 0.6096 - val_accuracy: 0.7809 - val_loss: 0.6214
# Epoch 209/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7857 - loss: 0.6103 - val_accuracy: 0.7825 - val_loss: 0.6171
# Epoch 210/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7856 - loss: 0.6110 - val_accuracy: 0.7814 - val_loss: 0.6199
# Epoch 211/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7846 - loss: 0.6118 - val_accuracy: 0.7800 - val_loss: 0.6226
# Epoch 212/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7860 - loss: 0.6095 - val_accuracy: 0.7838 - val_loss: 0.6142
# Epoch 213/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7856 - loss: 0.6094 - val_accuracy: 0.7843 - val_loss: 0.6128
# Epoch 214/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7849 - loss: 0.6109 - val_accuracy: 0.7808 - val_loss: 0.6210
# Epoch 215/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7856 - loss: 0.6106 - val_accuracy: 0.7839 - val_loss: 0.6143
# Epoch 216/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7849 - loss: 0.6100 - val_accuracy: 0.7808 - val_loss: 0.6212
# Epoch 217/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 35ms/step - accuracy: 0.7852 - loss: 0.6124 - val_accuracy: 0.7828 - val_loss: 0.6152
# Epoch 218/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7852 - loss: 0.6103 - val_accuracy: 0.7832 - val_loss: 0.6169
# Epoch 219/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7859 - loss: 0.6086 - val_accuracy: 0.7807 - val_loss: 0.6231
# Epoch 220/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7855 - loss: 0.6098 - val_accuracy: 0.7828 - val_loss: 0.6166
# Epoch 221/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.7857 - loss: 0.6090 - val_accuracy: 0.7833 - val_loss: 0.6154
# Epoch 222/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7855 - loss: 0.6104 - val_accuracy: 0.7837 - val_loss: 0.6144
# Epoch 223/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7854 - loss: 0.6087 - val_accuracy: 0.7836 - val_loss: 0.6151
# Epoch 224/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7867 - loss: 0.6076 - val_accuracy: 0.7769 - val_loss: 0.6330
# Epoch 225/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - accuracy: 0.7857 - loss: 0.6093 - val_accuracy: 0.7840 - val_loss: 0.6128
# Epoch 226/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7867 - loss: 0.6080 - val_accuracy: 0.7837 - val_loss: 0.6160
# Epoch 227/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.7865 - loss: 0.6072 - val_accuracy: 0.7841 - val_loss: 0.6132
# Epoch 228/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.7859 - loss: 0.6079 - val_accuracy: 0.7844 - val_loss: 0.6133
# Epoch 229/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 36ms/step - accuracy: 0.7854 - loss: 0.6086 - val_accuracy: 0.7791 - val_loss: 0.6285
# Epoch 230/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.7863 - loss: 0.6071 - val_accuracy: 0.7839 - val_loss: 0.6133
# Epoch 231/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.7863 - loss: 0.6082 - val_accuracy: 0.7841 - val_loss: 0.6152
# Epoch 232/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.7867 - loss: 0.6084 - val_accuracy: 0.7833 - val_loss: 0.6151
# Epoch 233/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 19s 38ms/step - accuracy: 0.7856 - loss: 0.6085 - val_accuracy: 0.7836 - val_loss: 0.6129
# Epoch 234/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.7860 - loss: 0.6075 - val_accuracy: 0.7837 - val_loss: 0.6153
# Epoch 235/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.7861 - loss: 0.6085 - val_accuracy: 0.7835 - val_loss: 0.6147
# Epoch 236/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.7851 - loss: 0.6110 - val_accuracy: 0.7823 - val_loss: 0.6172
# Epoch 237/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.7875 - loss: 0.6063 - val_accuracy: 0.7838 - val_loss: 0.6130
# Epoch 238/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.7846 - loss: 0.6114 - val_accuracy: 0.7840 - val_loss: 0.6144
# Epoch 239/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 36ms/step - accuracy: 0.7854 - loss: 0.6092 - val_accuracy: 0.7820 - val_loss: 0.6183
# Epoch 240/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.7856 - loss: 0.6085 - val_accuracy: 0.7832 - val_loss: 0.6154
# Epoch 241/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 35ms/step - accuracy: 0.7853 - loss: 0.6106 - val_accuracy: 0.7840 - val_loss: 0.6142
# Epoch 242/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 35ms/step - accuracy: 0.7851 - loss: 0.6091 - val_accuracy: 0.7824 - val_loss: 0.6183
# Epoch 243/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 35ms/step - accuracy: 0.7852 - loss: 0.6095 - val_accuracy: 0.7843 - val_loss: 0.6144
# Epoch 244/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 35ms/step - accuracy: 0.7865 - loss: 0.6074 - val_accuracy: 0.7839 - val_loss: 0.6129
# Epoch 245/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 35ms/step - accuracy: 0.7864 - loss: 0.6057 - val_accuracy: 0.7844 - val_loss: 0.6118
# Epoch 246/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.7866 - loss: 0.6074 - val_accuracy: 0.7843 - val_loss: 0.6123
# Epoch 247/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.7862 - loss: 0.6072 - val_accuracy: 0.7822 - val_loss: 0.6182
# Epoch 248/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 18s 36ms/step - accuracy: 0.7861 - loss: 0.6078 - val_accuracy: 0.7839 - val_loss: 0.6138
# Epoch 249/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.7875 - loss: 0.6056 - val_accuracy: 0.7845 - val_loss: 0.6115
# Epoch 250/250
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 17s 35ms/step - accuracy: 0.7858 - loss: 0.6089 - val_accuracy: 0.7826 - val_loss: 0.6183

# %%
model.save_weights('noPairs32.weights.h5')

# %%
import tensorflow as tf
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph
import time
import numpy as np

def get_flops(model, input_shape):
    input_tensor = tf.TensorSpec(input_shape, tf.float32)
    concrete_func = tf.function(model).get_concrete_function(input_tensor)
    
    frozen_func, graph_def = convert_variables_to_constants_v2_as_graph(concrete_func)
    
    with tf.Graph().as_default() as graph:
        tf.compat.v1.import_graph_def(graph_def, name='')
        run_meta = tf.compat.v1.RunMetadata()
        opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)
        return flops.total_float_ops


input_shape = [1] + list(x_val.shape[1:])
total_flops = get_flops(model, input_shape)
print("Total FLOPs for a single inference:", total_flops)

# ---------------------------
# Time Inference Per Event
# ---------------------------
import numpy as np
import time

_ = model(x_val[:10000])

num_trials = 100
inference_times = []
for _ in range(num_trials):
    start_time = time.perf_counter()
    _ = model(x_val[:10000])
    end_time = time.perf_counter()
    inference_times.append(end_time - start_time)

avg_inference_time_seconds = np.mean(np.array(inference_times) / 10000)
avg_inference_time_nanoseconds = avg_inference_time_seconds * 1e9

print("Average inference time per event:", np.round(avg_inference_time_nanoseconds,3), "nanoseconds")
# Out:
# 2025-03-27 14:26:51.910784: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-03-27 14:26:51.910847: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-03-27 14:26:51.910992: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-03-27 14:26:51.911005: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Total FLOPs for a single inference:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# BatchMatMulV2            183.30k float_ops (100.00%, 82.70%)
# Softmax                  20.50k float_ops (17.30%, 9.25%)
# RealDiv                  4.10k float_ops (8.05%, 1.85%)
# AddV2                    3.14k float_ops (6.20%, 1.41%)
# Mul                      3.07k float_ops (4.79%, 1.39%)
# BiasAdd                  2.58k float_ops (3.40%, 1.16%)
# Mean                     2.05k float_ops (2.24%, 0.92%)
# SquaredDifference        2.05k float_ops (1.31%, 0.92%)
# MatMul                     672 float_ops (0.39%, 0.30%)
# Rsqrt                      128 float_ops (0.09%, 0.06%)
# Neg                         64 float_ops (0.03%, 0.03%)
#
# ======================End of Report==========================
#  221646
# Average inference time per event: 3029.396 nanoseconds

# %%
x_val = np.load("/Users/anrunw/Downloads/l1-jet-id/data/jetid/processed/x_val_robust_32const_ptetaphi.npy")
y_val = np.load("/Users/anrunw/Downloads/l1-jet-id/data/jetid/processed/y_val_robust_32const_ptetaphi.npy")

# %%
xout = np.argmax(model(x_val, training=False),1)
yout = np.argmax(y_val,1)

# %%
import sklearn
sklearn.metrics.accuracy_score(xout,yout)
# Out:
# 0.7830076923076923

# %%
import matplotlib.pyplot as plt

# Suppose you have already trained your model:
# history = model.fit(...)

# Plotting the training & validation loss values
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss')
if 'val_loss' in history.history:
    plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# If you also have accuracy or other metrics, you can plot them similarly:
if 'accuracy' in history.history:
    plt.figure(figsize=(8, 6))
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    if 'val_accuracy' in history.history:
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import tensorflow as tf

# Define your class labels.
class_labels = ['g', 'q', 'W', 'Z', 't']

# Load your validation data.
# (Assuming x_val and y_val are already loaded in your environment)
# Get the model predictions as probabilities.
# If your model outputs logits, you may need to apply softmax first.
y_pred = model(x_val, training=False)

# Convert predictions and labels from TensorFlow tensors to NumPy arrays if needed.
if hasattr(y_pred, "numpy"):
    y_pred = y_pred.numpy()
if hasattr(y_val, "numpy"):
    y_val = y_val.numpy()

# Initialize dictionaries to store false positive rates, true positive rates, AUC, thresholds,
# interpolated FPR at target TPR, and accuracy at that threshold.
fpr = {}
tpr = {}
roc_auc = {}
thresholds_dict = {}
fpr_at_target = {}
accuracy_at_target = {}

# Target true positive rate.
target_tpr = 0.8

# Compute ROC curve, AUC, and interpolate FPR and threshold at target TPR for each class.
for i, label in enumerate(class_labels):
    # Compute ROC curve: returns fpr, tpr, and thresholds.
    fpr[i], tpr[i], thresholds = roc_curve(y_val[:, i], y_pred[:, i])
    thresholds_dict[i] = thresholds  # save thresholds for later use
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    # Check if the target TPR is reached.
    if target_tpr <= tpr[i][-1]:
        # Interpolate FPR at target TPR.
        fpr_at_target[label] = np.interp(target_tpr, tpr[i], fpr[i])
        # Interpolate threshold at target TPR.
        threshold_at_target = np.interp(target_tpr, tpr[i], thresholds)
        # Compute binary predictions for the current class using the interpolated threshold.
        preds_binary = (y_pred[:, i] >= threshold_at_target).astype(int)
        # Compute accuracy for the current class.
        accuracy = np.mean(preds_binary == y_val[:, i])
        accuracy_at_target[label] = accuracy
    else:
        fpr_at_target[label] = None  # If target TPR is not reached.
        accuracy_at_target[label] = None

# Display the 1/FPR values when TPR=80% for each class.
print("1/FPR at TPR=80% for each class:")
one_over_fpr = []
for label in class_labels:
    if fpr_at_target[label] is not None and fpr_at_target[label] != 0:
        inv_val = 1.0 / fpr_at_target[label]
        one_over_fpr.append(inv_val)
        print(f"{label}: 1/FPR = {inv_val}")
    else:
        print(f"{label}: undefined (FPR is None or zero)")

# Compute and print the average of 1/FPR across classes.
if one_over_fpr:
    avg_one_over_fpr = np.mean(one_over_fpr)
    print(f"Average 1/FPR across classes: {avg_one_over_fpr}")
else:
    print("No valid 1/FPR values to compute an average.")

# Print the accuracy at the FPR corresponding to TPR=80% for each class.
print("\nAccuracy at the threshold corresponding to TPR=80% for each class:")
accuracies = []
for label in class_labels:
    if accuracy_at_target[label] is not None:
        accuracies.append(accuracy_at_target[label])
        print(f"{label}: accuracy = {accuracy_at_target[label]:.4f}")
    else:
        print(f"{label}: accuracy undefined (target TPR not reached)")
if accuracies:
    avg_accuracy = np.mean(accuracies)
    print(f"Average accuracy across classes: {avg_accuracy:.4f}")
else:
    print("No valid accuracy values to compute an average.")

# Plot the ROC curves and mark the point corresponding to TPR=0.8.
plt.figure(figsize=(10, 8))
for i, label in enumerate(class_labels):
    plt.plot(fpr[i], tpr[i], label=f'ROC for class {label} (AUC = {roc_auc[i]:.2f})')
    if fpr_at_target[label] is not None:
        # Mark the point on the ROC curve where TPR = 0.8.
        plt.plot(fpr_at_target[label], target_tpr, 'o', label=f'{label} @ TPR=0.8')

# Plot the random chance line.
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Argmax Transformer - Average 1/FPR = ' + str(avg_one_over_fpr))
plt.legend(loc="lower right")
plt.show()
# Out:
# 1/FPR at TPR=80% for each class:
# g: 1/FPR = 9.18281948069182
# q: 1/FPR = 8.215652446675032
# W: 1/FPR = 35.346206192582514
# Z: 1/FPR = 44.75371687136393
# t: 1/FPR = 25.222546515870118
# Average 1/FPR across classes: 24.544188301436684
#
# Accuracy at the threshold corresponding to TPR=80% for each class:
# g: accuracy = 0.8727
# q: accuracy = 0.8631
# W: accuracy = 0.9372
# Z: accuracy = 0.9419
# t: accuracy = 0.9279
# Average accuracy across classes: 0.9086
