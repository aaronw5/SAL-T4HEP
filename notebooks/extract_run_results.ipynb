# %%
#!/usr/bin/env python3
import os
import re

# metric names remain the same
METRIC_KEYS = [
    "FLOPs per inference",
    "Avg inference time per event (ns)",
    "Validation accuracy",
    "1/FPR@TPR=0.8 for g",
    "1/FPR@TPR=0.8 for q",
    "1/FPR@TPR=0.8 for W",
    "1/FPR@TPR=0.8 for Z",
    "1/FPR@TPR=0.8 for t",
    "Average 1/FPR",
    "Total params",
    "Trainable params",
]

LOG_LINE_RE = re.compile(
    r'^(?P<ts>\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2},\d+)\s+INFO\s+'
    r'(?P<key>[^:]+):\s+(?P<val>.+)$'
)

def find_root_dirs(start_path):
    """
    Find **all** subdirectories under start_path that contain both
    train.log and acc_curve.png.
    """
    matches = []
    for dirpath, dirnames, filenames in os.walk(start_path):
        if "train.log" in filenames and "acc_curve.png" in filenames:
            matches.append(dirpath)
    return matches
    # ⇒ CHANGED: collects all matches instead of returning on the first one

def parse_log(log_path):
    """
    Read train.log and extract keys in METRIC_KEYS.
    """
    results = {}
    with open(log_path, 'r') as f:
        for line in f:
            m = LOG_LINE_RE.match(line.strip())
            if not m:
                continue
            key = m.group("key")
            if key in METRIC_KEYS:
                results[key] = {
                    "timestamp": m.group("ts"),
                    "value": m.group("val")
                }
    return results

def main():
    # You can swap this for argparse if you like
    root_path = '/j-jepa-vol/linformer4HEP/runs'

    roots = find_root_dirs(root_path)
    if not roots:
        print(f"ERROR: No directory under {root_path} contains train.log and acc_curve.png")
        return

    # ⇒ CHANGED: loop through **all** matching directories
    for root in roots:
        print(f"\n=== Processing {root} ===")
        log_file = os.path.join(root, "train.log")
        metrics = parse_log(log_file)

        if not metrics:
            print(f"WARNING: No metrics found in {log_file}")
            continue

        print(f"Extracted metrics from {log_file}:")
        for key in METRIC_KEYS:
            if key in metrics:
                ts = metrics[key]["timestamp"]
                val = metrics[key]["value"]
                print(f"{ts} INFO {key}: {val}")
            else:
                print(f"(not found) {key}")

# %%
main()
# Out:
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_f/150/pt ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_f/150/pt/train.log:
# 2025-04-19 05:38:13,703 INFO FLOPs per inference: 2045730
# 2025-04-19 05:38:14,183 INFO Avg inference time per event (ns): 5354.795
# 2025-04-19 05:38:15,709 INFO Validation accuracy: 0.8063
# 2025-04-19 05:38:16,243 INFO 1/FPR@TPR=0.8 for g: 12.900
# 2025-04-19 05:38:16,243 INFO 1/FPR@TPR=0.8 for q: 9.495
# 2025-04-19 05:38:16,243 INFO 1/FPR@TPR=0.8 for W: 48.781
# 2025-04-19 05:38:16,243 INFO 1/FPR@TPR=0.8 for Z: 74.138
# 2025-04-19 05:38:16,243 INFO 1/FPR@TPR=0.8 for t: 30.763
# 2025-04-19 05:38:16,243 INFO Average 1/FPR: 35.215
# 2025-04-19 02:56:47,758 INFO Total params: 16917 (66.08 KB)
# 2025-04-19 02:56:47,758 INFO Trainable params: 16917 (66.08 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_f/150/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_f/150/delta_R/train.log:
# 2025-04-19 08:18:48,156 INFO FLOPs per inference: 2045730
# 2025-04-19 08:18:48,673 INFO Avg inference time per event (ns): 5812.295
# 2025-04-19 08:18:50,258 INFO Validation accuracy: 0.8030
# 2025-04-19 08:18:50,795 INFO 1/FPR@TPR=0.8 for g: 12.834
# 2025-04-19 08:18:50,795 INFO 1/FPR@TPR=0.8 for q: 9.612
# 2025-04-19 08:18:50,795 INFO 1/FPR@TPR=0.8 for W: 47.745
# 2025-04-19 08:18:50,795 INFO 1/FPR@TPR=0.8 for Z: 61.179
# 2025-04-19 08:18:50,795 INFO 1/FPR@TPR=0.8 for t: 30.127
# 2025-04-19 08:18:50,795 INFO Average 1/FPR: 32.299
# 2025-04-19 05:38:29,583 INFO Total params: 16917 (66.08 KB)
# 2025-04-19 05:38:29,583 INFO Trainable params: 16917 (66.08 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_f/16/pt ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_f/16/pt/train.log:
# 2025-04-19 01:15:45,093 INFO FLOPs per inference: 220382
# 2025-04-19 01:15:45,311 INFO Avg inference time per event (ns): 2146.188
# 2025-04-19 01:15:45,795 INFO Validation accuracy: 0.7383
# 2025-04-19 01:15:46,339 INFO 1/FPR@TPR=0.8 for g: 6.223
# 2025-04-19 01:15:46,339 INFO 1/FPR@TPR=0.8 for q: 6.810
# 2025-04-19 01:15:46,339 INFO 1/FPR@TPR=0.8 for W: 16.266
# 2025-04-19 01:15:46,339 INFO 1/FPR@TPR=0.8 for Z: 15.257
# 2025-04-19 01:15:46,339 INFO 1/FPR@TPR=0.8 for t: 18.595
# 2025-04-19 01:15:46,339 INFO Average 1/FPR: 12.630
# 2025-04-19 00:51:22,833 INFO Total params: 7765 (30.33 KB)
# 2025-04-19 00:51:22,834 INFO Trainable params: 7765 (30.33 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_f/16/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_f/16/delta_R/train.log:
# 2025-04-19 01:39:56,539 INFO FLOPs per inference: 220382
# 2025-04-19 01:39:56,752 INFO Avg inference time per event (ns): 2230.230
# 2025-04-19 01:39:57,223 INFO Validation accuracy: 0.7368
# 2025-04-19 01:39:57,766 INFO 1/FPR@TPR=0.8 for g: 6.180
# 2025-04-19 01:39:57,766 INFO 1/FPR@TPR=0.8 for q: 6.794
# 2025-04-19 01:39:57,766 INFO 1/FPR@TPR=0.8 for W: 16.425
# 2025-04-19 01:39:57,766 INFO 1/FPR@TPR=0.8 for Z: 14.715
# 2025-04-19 01:39:57,766 INFO 1/FPR@TPR=0.8 for t: 18.491
# 2025-04-19 01:39:57,766 INFO Average 1/FPR: 12.521
# 2025-04-19 01:15:51,471 INFO Total params: 7765 (30.33 KB)
# 2025-04-19 01:15:51,471 INFO Trainable params: 7765 (30.33 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_f/32/pt ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_f/32/pt/train.log:
# 2025-04-19 02:18:12,883 INFO FLOPs per inference: 438334
# 2025-04-19 02:18:13,100 INFO Avg inference time per event (ns): 2256.334
# 2025-04-19 02:18:13,724 INFO Validation accuracy: 0.7893
# 2025-04-19 02:18:14,269 INFO 1/FPR@TPR=0.8 for g: 9.975
# 2025-04-19 02:18:14,269 INFO 1/FPR@TPR=0.8 for q: 8.709
# 2025-04-19 02:18:14,269 INFO 1/FPR@TPR=0.8 for W: 34.736
# 2025-04-19 02:18:14,269 INFO 1/FPR@TPR=0.8 for Z: 45.834
# 2025-04-19 02:18:14,269 INFO 1/FPR@TPR=0.8 for t: 27.516
# 2025-04-19 02:18:14,269 INFO Average 1/FPR: 25.354
# 2025-04-19 01:40:09,259 INFO Total params: 8853 (34.58 KB)
# 2025-04-19 01:40:09,259 INFO Trainable params: 8853 (34.58 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_f/32/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_f/32/delta_R/train.log:
# 2025-04-19 02:56:23,142 INFO FLOPs per inference: 438334
# 2025-04-19 02:56:23,354 INFO Avg inference time per event (ns): 2183.791
# 2025-04-19 02:56:23,976 INFO Validation accuracy: 0.7880
# 2025-04-19 02:56:24,508 INFO 1/FPR@TPR=0.8 for g: 9.840
# 2025-04-19 02:56:24,508 INFO 1/FPR@TPR=0.8 for q: 8.655
# 2025-04-19 02:56:24,508 INFO 1/FPR@TPR=0.8 for W: 33.501
# 2025-04-19 02:56:24,508 INFO 1/FPR@TPR=0.8 for Z: 44.238
# 2025-04-19 02:56:24,508 INFO 1/FPR@TPR=0.8 for t: 27.531
# 2025-04-19 02:56:24,508 INFO Average 1/FPR: 24.753
# 2025-04-19 02:18:20,242 INFO Total params: 8853 (34.58 KB)
# 2025-04-19 02:18:20,242 INFO Trainable params: 8853 (34.58 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_e/150/pt ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_e/150/pt/train.log:
# 2025-04-19 03:47:20,105 INFO FLOPs per inference: 2045730
# 2025-04-19 03:47:20,426 INFO Avg inference time per event (ns): 3453.307
# 2025-04-19 03:47:21,916 INFO Validation accuracy: 0.8079
# 2025-04-19 03:47:22,448 INFO 1/FPR@TPR=0.8 for g: 13.198
# 2025-04-19 03:47:22,448 INFO 1/FPR@TPR=0.8 for q: 9.627
# 2025-04-19 03:47:22,448 INFO 1/FPR@TPR=0.8 for W: 49.963
# 2025-04-19 03:47:22,448 INFO 1/FPR@TPR=0.8 for Z: 72.937
# 2025-04-19 03:47:22,448 INFO 1/FPR@TPR=0.8 for t: 30.792
# 2025-04-19 03:47:22,448 INFO Average 1/FPR: 35.303
# 2025-04-19 02:20:23,451 INFO Total params: 16917 (66.08 KB)
# 2025-04-19 02:20:23,451 INFO Trainable params: 16917 (66.08 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_e/150/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_e/150/delta_R/train.log:
# 2025-04-19 05:14:02,515 INFO FLOPs per inference: 2045730
# 2025-04-19 05:14:02,837 INFO Avg inference time per event (ns): 3475.274
# 2025-04-19 05:14:04,163 INFO Validation accuracy: 0.8064
# 2025-04-19 05:14:04,694 INFO 1/FPR@TPR=0.8 for g: 13.378
# 2025-04-19 05:14:04,694 INFO 1/FPR@TPR=0.8 for q: 9.590
# 2025-04-19 05:14:04,694 INFO 1/FPR@TPR=0.8 for W: 45.970
# 2025-04-19 05:14:04,694 INFO 1/FPR@TPR=0.8 for Z: 68.074
# 2025-04-19 05:14:04,694 INFO 1/FPR@TPR=0.8 for t: 32.499
# 2025-04-19 05:14:04,694 INFO Average 1/FPR: 33.902
# 2025-04-19 03:47:33,729 INFO Total params: 16917 (66.08 KB)
# 2025-04-19 03:47:33,729 INFO Trainable params: 16917 (66.08 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_e/16/pt ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_e/16/pt/train.log:
# 2025-04-19 01:06:13,402 INFO FLOPs per inference: 220382
# 2025-04-19 01:06:13,619 INFO Avg inference time per event (ns): 2160.435
# 2025-04-19 01:06:14,091 INFO Validation accuracy: 0.7381
# 2025-04-19 01:06:14,627 INFO 1/FPR@TPR=0.8 for g: 6.269
# 2025-04-19 01:06:14,627 INFO 1/FPR@TPR=0.8 for q: 6.806
# 2025-04-19 01:06:14,627 INFO 1/FPR@TPR=0.8 for W: 16.411
# 2025-04-19 01:06:14,627 INFO 1/FPR@TPR=0.8 for Z: 15.368
# 2025-04-19 01:06:14,627 INFO 1/FPR@TPR=0.8 for t: 18.564
# 2025-04-19 01:06:14,627 INFO Average 1/FPR: 12.684
# 2025-04-19 00:46:23,132 INFO Total params: 7765 (30.33 KB)
# 2025-04-19 00:46:23,132 INFO Trainable params: 7765 (30.33 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_e/16/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_e/16/delta_R/train.log:
# 2025-04-19 01:26:13,685 INFO FLOPs per inference: 220382
# 2025-04-19 01:26:13,921 INFO Avg inference time per event (ns): 2479.224
# 2025-04-19 01:26:14,435 INFO Validation accuracy: 0.7367
# 2025-04-19 01:26:14,972 INFO 1/FPR@TPR=0.8 for g: 6.160
# 2025-04-19 01:26:14,972 INFO 1/FPR@TPR=0.8 for q: 6.737
# 2025-04-19 01:26:14,972 INFO 1/FPR@TPR=0.8 for W: 16.178
# 2025-04-19 01:26:14,972 INFO 1/FPR@TPR=0.8 for Z: 14.985
# 2025-04-19 01:26:14,972 INFO 1/FPR@TPR=0.8 for t: 18.419
# 2025-04-19 01:26:14,972 INFO Average 1/FPR: 12.496
# 2025-04-19 01:06:20,084 INFO Total params: 7765 (30.33 KB)
# 2025-04-19 01:06:20,084 INFO Trainable params: 7765 (30.33 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_e/32/pt ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_e/32/pt/train.log:
# 2025-04-19 01:53:12,967 INFO FLOPs per inference: 438334
# 2025-04-19 01:53:13,178 INFO Avg inference time per event (ns): 2245.532
# 2025-04-19 01:53:13,771 INFO Validation accuracy: 0.7904
# 2025-04-19 01:53:14,312 INFO 1/FPR@TPR=0.8 for g: 9.918
# 2025-04-19 01:53:14,312 INFO 1/FPR@TPR=0.8 for q: 8.776
# 2025-04-19 01:53:14,312 INFO 1/FPR@TPR=0.8 for W: 37.601
# 2025-04-19 01:53:14,312 INFO 1/FPR@TPR=0.8 for Z: 49.549
# 2025-04-19 01:53:14,312 INFO 1/FPR@TPR=0.8 for t: 27.124
# 2025-04-19 01:53:14,312 INFO Average 1/FPR: 26.594
# 2025-04-19 01:26:21,369 INFO Total params: 8853 (34.58 KB)
# 2025-04-19 01:26:21,369 INFO Trainable params: 8853 (34.58 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_e/32/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_e/32/delta_R/train.log:
# 2025-04-19 02:20:10,328 INFO FLOPs per inference: 438334
# 2025-04-19 02:20:10,539 INFO Avg inference time per event (ns): 2223.136
# 2025-04-19 02:20:11,129 INFO Validation accuracy: 0.7910
# 2025-04-19 02:20:11,663 INFO 1/FPR@TPR=0.8 for g: 10.173
# 2025-04-19 02:20:11,663 INFO 1/FPR@TPR=0.8 for q: 8.772
# 2025-04-19 02:20:11,663 INFO 1/FPR@TPR=0.8 for W: 36.277
# 2025-04-19 02:20:11,663 INFO 1/FPR@TPR=0.8 for Z: 47.143
# 2025-04-19 02:20:11,663 INFO 1/FPR@TPR=0.8 for t: 27.701
# 2025-04-19 02:20:11,663 INFO Average 1/FPR: 26.013
# 2025-04-19 01:53:20,627 INFO Total params: 8853 (34.58 KB)
# 2025-04-19 01:53:20,627 INFO Trainable params: 8853 (34.58 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/exp003/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/exp003/delta_R/train.log:
# 2025-04-18 20:44:58,923 INFO FLOPs per inference: 319454
# 2025-04-18 20:44:59,136 INFO Avg inference time per event (ns): 2271.353
# 2025-04-18 20:44:59,621 INFO Validation accuracy: 0.6910
# 2025-04-18 20:45:00,132 INFO 1/FPR@TPR=0.8 for g: 4.960
# 2025-04-18 20:45:00,132 INFO 1/FPR@TPR=0.8 for q: 5.602
# 2025-04-18 20:45:00,132 INFO 1/FPR@TPR=0.8 for W: 9.538
# 2025-04-18 20:45:00,132 INFO 1/FPR@TPR=0.8 for Z: 7.651
# 2025-04-18 20:45:00,132 INFO 1/FPR@TPR=0.8 for t: 14.063
# 2025-04-18 20:45:00,132 INFO Average 1/FPR: 8.363
# 2025-04-18 20:44:42,284 INFO Total params: 9925 (38.77 KB)
# 2025-04-18 20:44:42,284 INFO Trainable params: 9925 (38.77 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/exp003/32/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/exp003/32/delta_R/train.log:
# 2025-04-18 20:49:26,967 INFO FLOPs per inference: 636478
# 2025-04-18 20:49:27,180 INFO Avg inference time per event (ns): 2261.866
# 2025-04-18 20:49:27,788 INFO Validation accuracy: 0.7525
# 2025-04-18 20:49:28,317 INFO 1/FPR@TPR=0.8 for g: 7.655
# 2025-04-18 20:49:28,317 INFO 1/FPR@TPR=0.8 for q: 7.500
# 2025-04-18 20:49:28,317 INFO 1/FPR@TPR=0.8 for W: 17.745
# 2025-04-18 20:49:28,318 INFO 1/FPR@TPR=0.8 for Z: 17.247
# 2025-04-18 20:49:28,318 INFO 1/FPR@TPR=0.8 for t: 19.488
# 2025-04-18 20:49:28,318 INFO Average 1/FPR: 13.927
# 2025-04-18 20:49:05,150 INFO Total params: 10053 (39.27 KB)
# 2025-04-18 20:49:05,150 INFO Trainable params: 10053 (39.27 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/exp002 ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/exp002/train.log:
# 2025-04-18 20:36:11,702 INFO FLOPs per inference: 319454
# 2025-04-18 20:36:11,923 INFO Avg inference time per event (ns): 2276.581
# 2025-04-18 20:36:12,463 INFO Validation accuracy: 0.6917
# 2025-04-18 20:36:13,200 INFO 1/FPR@TPR=0.8 for g: 4.916
# 2025-04-18 20:36:13,200 INFO 1/FPR@TPR=0.8 for q: 5.588
# 2025-04-18 20:36:13,200 INFO 1/FPR@TPR=0.8 for W: 9.327
# 2025-04-18 20:36:13,200 INFO 1/FPR@TPR=0.8 for Z: 7.563
# 2025-04-18 20:36:13,200 INFO 1/FPR@TPR=0.8 for t: 14.315
# 2025-04-18 20:36:13,200 INFO Average 1/FPR: 8.342
# 2025-04-18 20:35:53,994 INFO Total params: 9925 (38.77 KB)
# 2025-04-18 20:35:53,994 INFO Trainable params: 9925 (38.77 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_both/150/pt ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_both/150/pt/train.log:
# 2025-04-19 03:19:52,771 INFO FLOPs per inference: 2045730
# 2025-04-19 03:19:53,098 INFO Avg inference time per event (ns): 3583.834
# 2025-04-19 03:19:54,228 INFO Validation accuracy: 0.8090
# 2025-04-19 03:19:54,771 INFO 1/FPR@TPR=0.8 for g: 13.498
# 2025-04-19 03:19:54,771 INFO 1/FPR@TPR=0.8 for q: 9.737
# 2025-04-19 03:19:54,771 INFO 1/FPR@TPR=0.8 for W: 50.115
# 2025-04-19 03:19:54,771 INFO 1/FPR@TPR=0.8 for Z: 71.463
# 2025-04-19 03:19:54,771 INFO 1/FPR@TPR=0.8 for t: 33.219
# 2025-04-19 03:19:54,771 INFO Average 1/FPR: 35.606
# 2025-04-19 01:50:42,237 INFO Total params: 7957 (31.08 KB)
# 2025-04-19 01:50:42,237 INFO Trainable params: 7957 (31.08 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_both/150/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_both/150/delta_R/train.log:
# 2025-04-19 04:49:12,123 INFO FLOPs per inference: 2045730
# 2025-04-19 04:49:12,456 INFO Avg inference time per event (ns): 3617.299
# 2025-04-19 04:49:13,558 INFO Validation accuracy: 0.8044
# 2025-04-19 04:49:14,098 INFO 1/FPR@TPR=0.8 for g: 13.353
# 2025-04-19 04:49:14,098 INFO 1/FPR@TPR=0.8 for q: 9.423
# 2025-04-19 04:49:14,098 INFO 1/FPR@TPR=0.8 for W: 41.444
# 2025-04-19 04:49:14,098 INFO 1/FPR@TPR=0.8 for Z: 61.103
# 2025-04-19 04:49:14,098 INFO 1/FPR@TPR=0.8 for t: 32.467
# 2025-04-19 04:49:14,098 INFO Average 1/FPR: 31.558
# 2025-04-19 03:20:05,580 INFO Total params: 7957 (31.08 KB)
# 2025-04-19 03:20:05,580 INFO Trainable params: 7957 (31.08 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_both/16/pt ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_both/16/pt/train.log:
# 2025-04-19 00:34:28,782 INFO FLOPs per inference: 220382
# 2025-04-19 00:34:29,005 INFO Avg inference time per event (ns): 2238.691
# 2025-04-19 00:34:29,327 INFO Validation accuracy: 0.7391
# 2025-04-19 00:34:30,144 INFO 1/FPR@TPR=0.8 for g: 6.204
# 2025-04-19 00:34:30,144 INFO 1/FPR@TPR=0.8 for q: 6.837
# 2025-04-19 00:34:30,144 INFO 1/FPR@TPR=0.8 for W: 16.890
# 2025-04-19 00:34:30,144 INFO 1/FPR@TPR=0.8 for Z: 15.630
# 2025-04-19 00:34:30,144 INFO 1/FPR@TPR=0.8 for t: 18.561
# 2025-04-19 00:34:30,144 INFO Average 1/FPR: 12.824
# 2025-04-19 00:14:42,491 INFO Total params: 6805 (26.58 KB)
# 2025-04-19 00:14:42,491 INFO Trainable params: 6805 (26.58 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_both/16/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_both/16/delta_R/train.log:
# 2025-04-19 00:54:18,639 INFO FLOPs per inference: 220382
# 2025-04-19 00:54:18,851 INFO Avg inference time per event (ns): 2269.149
# 2025-04-19 00:54:19,176 INFO Validation accuracy: 0.7393
# 2025-04-19 00:54:19,843 INFO 1/FPR@TPR=0.8 for g: 6.212
# 2025-04-19 00:54:19,843 INFO 1/FPR@TPR=0.8 for q: 6.847
# 2025-04-19 00:54:19,843 INFO 1/FPR@TPR=0.8 for W: 17.136
# 2025-04-19 00:54:19,843 INFO 1/FPR@TPR=0.8 for Z: 15.947
# 2025-04-19 00:54:19,843 INFO 1/FPR@TPR=0.8 for t: 18.547
# 2025-04-19 00:54:19,843 INFO Average 1/FPR: 12.938
# 2025-04-19 00:34:35,469 INFO Total params: 6805 (26.58 KB)
# 2025-04-19 00:34:35,469 INFO Trainable params: 6805 (26.58 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_both/32/pt ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_both/32/pt/train.log:
# 2025-04-19 01:22:19,543 INFO FLOPs per inference: 438334
# 2025-04-19 01:22:19,772 INFO Avg inference time per event (ns): 2325.594
# 2025-04-19 01:22:20,241 INFO Validation accuracy: 0.7906
# 2025-04-19 01:22:20,821 INFO 1/FPR@TPR=0.8 for g: 9.960
# 2025-04-19 01:22:20,821 INFO 1/FPR@TPR=0.8 for q: 8.848
# 2025-04-19 01:22:20,821 INFO 1/FPR@TPR=0.8 for W: 36.144
# 2025-04-19 01:22:20,821 INFO 1/FPR@TPR=0.8 for Z: 48.293
# 2025-04-19 01:22:20,821 INFO 1/FPR@TPR=0.8 for t: 27.463
# 2025-04-19 01:22:20,821 INFO Average 1/FPR: 26.142
# 2025-04-19 00:54:32,629 INFO Total params: 6933 (27.08 KB)
# 2025-04-19 00:54:32,629 INFO Trainable params: 6933 (27.08 KB)
#
# === Processing /j-jepa-vol/linformer4HEP/runs/cluster_both/32/delta_R ===
# Extracted metrics from /j-jepa-vol/linformer4HEP/runs/cluster_both/32/delta_R/train.log:
# 2025-04-19 01:50:16,493 INFO FLOPs per inference: 438334
# 2025-04-19 01:50:16,717 INFO Avg inference time per event (ns): 2364.495
# 2025-04-19 01:50:17,156 INFO Validation accuracy: 0.7925
# 2025-04-19 01:50:17,699 INFO 1/FPR@TPR=0.8 for g: 10.030
# 2025-04-19 01:50:17,699 INFO 1/FPR@TPR=0.8 for q: 8.956
# 2025-04-19 01:50:17,699 INFO 1/FPR@TPR=0.8 for W: 36.026
# 2025-04-19 01:50:17,699 INFO 1/FPR@TPR=0.8 for Z: 50.355
# 2025-04-19 01:50:17,699 INFO 1/FPR@TPR=0.8 for t: 27.896
# 2025-04-19 01:50:17,699 INFO Average 1/FPR: 26.653
# 2025-04-19 01:22:28,525 INFO Total params: 6933 (27.08 KB)
# 2025-04-19 01:22:28,525 INFO Trainable params: 6933 (27.08 KB)
